# %% [markdown]
# # Question 1
# ## a)
# C

# %% [markdown]
# ## b)
# Y = {A, B, C, D, E, F}

# %% [markdown]
# ## c)
# X = { x ∈ R | x >= 0}

# %% [markdown]
# ## d)
# X = {(x1, x2)| x1 ∈ R and x1 >=0 and x2 ∈{0, 1}}

# %% [markdown]
# ## e)
# f(x) = {
# if scored perfect on HW 1 AND<br>
#     if x >= 6.5, A<br>
#     if 3.5 > x >= 4.5, B<br>
#     if 4.5 > x >= 2.5, C <br>
#     if 1.5 > x >= 0, D<br>
#
# if scored imperfectly on HW1 AND<br>
#     if x >=10, A<br>
#     if 10 > x >= 8, B<br>
#     if 8 > x >= 6, C <br>
#     if 6 > x >= 4, D<br>
#     if 4 > x >= 0, D<br>

# %% [markdown]
# ## Question 2

# %% [markdown]
# ## a)
# Y = [a+b, a-b]

# %% [markdown]
# ## b)
# a will be the mean f(x)<br>
# b should be range of temp in a year divided by 2<br>
# theta offsets the peak of the sin wave by (hottest day/ (2*pi)) <br>
# T = number of days between 2 hottest days <br>

# %% [markdown]
# ## c)
# 2

# %% [markdown]
# ## d)
# 365

# %% [markdown]
# ## e)
# model 1 require less data points but may not generalize well to all locations <br>
# model 2 require more data points but genralizes well
